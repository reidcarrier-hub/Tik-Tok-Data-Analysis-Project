# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("tiktok_dataset.csv")

# %%
# Display and examine the first ten rows of the dataframe
data.head(10)
# Out:
#     # claim_status    video_id  video_duration_sec  \
# 0   1        claim  7017666017                  59
# 1   2        claim  4014381136                  32
# 2   3        claim  9859838091                  31
# 3   4        claim  1866847991                  25
# 4   5        claim  7105231098                  19
# 5   6        claim  8972200955                  35
# 6   7        claim  4958886992                  16
# 7   8        claim  2270982263                  41
# 8   9        claim  5235769692                  50
# 9  10        claim  4660861094                  45
#
#                             video_transcription_text verified_status  \
# 0  someone shared with me that drone deliveries a...    not verified
# 1  someone shared with me that there are more mic...    not verified
# 2  someone shared with me that american industria...    not verified
# 3  someone shared with me that the metro of st. p...    not verified
# ...

# %% [raw]
# Question 1: When reviewing the first few rows of the dataframe, what do I observe about the data? What does each row represent?
# - Claim_status shows us whether an authors video is under claim or opinion status
# - Each video has a unique identifier in the video_id column
# - The video_transcription_text contains the written/spoken content of the video, showing what claim has been made
# - The author being Verified or Not Verified is shown in the verified_status column
# - The author_ban_status shows whether or not the author has been banned or under review
# - The remaining columns, video_view_count, video_like_count, video_share_count, video_download_count, video_comment_count, all show engagement metrics

# %%
# Get summary info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19382 entries, 0 to 19381
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   #                         19382 non-null  int64
#  1   claim_status              19084 non-null  object
#  2   video_id                  19382 non-null  int64
#  3   video_duration_sec        19382 non-null  int64
#  4   video_transcription_text  19084 non-null  object
#  5   verified_status           19382 non-null  object
#  6   author_ban_status         19382 non-null  object
#  7   video_view_count          19084 non-null  float64
#  8   video_like_count          19084 non-null  float64
#  9   video_share_count         19084 non-null  float64
#  10  video_download_count      19084 non-null  float64
#  11  video_comment_count       19084 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 1.8+ MB

# %% [raw]
# Question 2: When reviewing the data.info() output, what do I notice about the different variables? Are there any null values? Are all of the variables numeric? Does anything else stand out?
#
# There are null values within the data as not all variables have a non-null value of 19382
# claim_status
# video_transcription_text
# video_view_count
# video_like_count
# video_share_count
# video_download_count
# video_comment_count
# These variables are missing values mostly because they are new videos and have low engagement at the moment. The variables could also be missing content labels as well
#
# Not all variables are numeric types:
# int64 - integer numeric value
# float64 - decimal numeric value
# object value means they have a text/categorical value
#
# The "#" column is being used as an identifer for each claim/opinion and can probably be removed later
#
# The dataset contains a mix of numerical and categorical variables, includes some missing values, and may require data cleaning before analysis—especially handling null values and deciding whether the # column is necessary

# %%
# Get summary statistics
data.describe()
# Out:
#                   #      video_id  video_duration_sec  video_view_count  \
# count  19382.000000  1.938200e+04        19382.000000      19084.000000
# mean    9691.500000  5.627454e+09           32.421732     254708.558688
# std     5595.245794  2.536440e+09           16.229967     322893.280814
# min        1.000000  1.234959e+09            5.000000         20.000000
# 25%     4846.250000  3.430417e+09           18.000000       4942.500000
# 50%     9691.500000  5.618664e+09           32.000000       9954.500000
# 75%    14536.750000  7.843960e+09           47.000000     504327.000000
# max    19382.000000  9.999873e+09           60.000000     999817.000000
#
#        video_like_count  video_share_count  video_download_count  \
# count      19084.000000       19084.000000          19084.000000
# mean       84304.636030       16735.248323           1049.429627
# std       133420.546814       32036.174350           2004.299894
# ...

# %% [raw]
# Question 3: When reviewing the data.describe() output, what do you notice about the distributions of each variable? Are there any questionable values? Does it seem that there are outlier values?
#
# Columns like:
#
# video_view_count
# video_like_count
# video_share_count
# video_download_count
# video_comment_count
#
# Are skewed to the right
#
# Example:
# Median video_view_count = 9,954.5
# Mean video_view_count = 254,708.6
#
# This means that a small number of the videos have most of the views
#
# The maximum values are much larger than the 75th percentile
#
# Example for views:
#
# 75th percentile = 504,327
# Maximum = 999,817
#
# Example for likes:
#
# 75th percentile = 125,020
# Maximum = 657,830
#
# This means there are likely significant outliers
#
# video_duration_sec looks normally limited
# Minimum = 5 seconds
# Maximum = 60 seconds
# Mean = 32.4 seconds
#
# This appears reasonable and likely reflects a platform-imposed time range rather than unusual values
#
# video_id is not analytically meaningful
#
# Although included in describe(), video_id is just an identifier and does not provide useful statistical insight
#
# The same applies somewhat to the # column since it is simply a row number

# %%
# What are the different values for claim status and how many of each are in the data?
data['claim_status'].value_counts()
# Out:
# claim_status
# claim      9608
# opinion    9476
# Name: count, dtype: int64

# %% [raw]
# Question: What do I notice about the values shown?
# There are currently more claims than opinions, with only a difference of 132
#
# This means that the values for claim status are balanced which makes predictions or comparisons more reliable
#
# 9608 + 9476 = 19084 which is less than 19382, which is the claim status total. This matches the number of non-null values seen earlier for claim_status, confirming that the remaining 298 rows have missing values (NaN) for this column.
#
#
# Next, examine the engagement trends associated with each different claim status.
#
# Start by using Boolean masking to filter the data according to claim status, then calculate the mean and median view counts for each claim status

# %%
# What is the average view count of videos with "claim" status?
claims = data[data['claim_status']=='claim']
print('Mean view count of videos with claim status is: ', claims['video_view_count'].mean())
print('Median view count of videos with claim statis is: ', claims['video_view_count'].median())
# Out:
# Mean view count of videos with claim status is:  501029.4527477102
# Median view count of videos with claim statis is:  501555.0

# %%
# What is the average view count of videos with "opinion" status?
opinions = data[data['claim_status']=='opinion']
print('Mean view count of videos of opinion status: ', opinions['video_view_count'].mean())
print('Median view count of videos of opinion status: ', opinions['video_view_count'].median())
# Out:
# Mean view count of videos of opinion status:  4956.43224989447
# Median view count of videos of opinion status:  4953.0

# %% [raw]
# Question: What do I notice about the mean and media within each claim category?
#
# The mean and median are extremely close in both categories. Since the mean and median are nearly the same in both groups, this suggests that the view counts within each category are relatively evenly distributed and not heavily distorted by extreme outliers within that group.
#
# The difference between categories is extremely large:
#
# Claim videos average around 500,000 views
# Opinion videos average around 5,000 views
#
# This means claim-based videos receive roughly 100 times more views than opinion-based videos.
#
# This suggests a strong relationship between claim status and engagement
#
# Videos labeled as claims appear to attract significantly more attention and reach much larger audiences than opinion videos.
#
# This could indicate that factual-sounding or controversial claim-based content tends to spread more widely than personal opinions.
#
# The biggest takeaway is that claim videos perform dramatically better in view count than opinion videos, while the similarity between mean and median suggests the results are consistent across most videos rather than being driven by only a few viral posts.
#
#
#
# Now, examine trends associated with the ban status of the author.
#
# Use groupby() to calculate how many videos there are for each combination of categories of claim status and author ban status.

# %%
# Get counts for each group combination of claim status and author ban status
data.groupby(['claim_status','author_ban_status']).count()[['#']]
# Out:
#                                    #
# claim_status author_ban_status
# claim        active             6566
#              banned             1439
#              under review       1603
# opinion      active             8817
#              banned              196
#              under review        463

# %% [raw]
# Question: What do I notice about the number of claims videos with banned authors? Why might this relationship occur?
#
# Comparing banned authors
# Claim videos with banned authors: 1,439
# Opinion videos with banned authors: 196
# Claim videos seem to have more people banned than people banned for Opinion videos
#
# A likely reason is that claim-based videos often contain statements presented as facts, which may include:
#
# misinformation
# false claims
# misleading health or political content
# harmful or policy-violating statements
#
# Opinion-based videos are usually personal beliefs or preferences, such as:
#
# “I think this movie is overrated”
# “In my opinion, this is the best investment strategy”
#
# These are less likely to violate platform rules because they are not presented as objective facts.
#
# The strong difference suggests a relationship between claim-based content and moderation risk—authors posting claim videos may face bans more often because factual misinformation is more likely to trigger enforcement actions than personal opinions.
#
#
# Continue investigating engagement levels, now focusing on author_ban_status.
#
# Calculate the median video share count of each author ban status.

# %%
# Calculate the median video share count of each author ban status
data.groupby(['author_ban_status']).agg({'video_like_count': ['mean','median'],'video_view_count':['mean','median'],'video_share_count':['mean','median']})
# Out:
#                   video_like_count           video_view_count            \
#                               mean    median             mean    median
# author_ban_status
# active                71036.533836    2222.0    215927.039524    8616.0
# banned               153017.236697  105573.0    445845.439144  448201.0
# under review         128718.050339   71204.5    392204.836399  365245.5
#
#                   video_share_count
#                                mean   median
# author_ban_status
# active                 14111.466164    437.0
# banned                 29998.942508  14468.0
# under review           25774.696999   9444.0

# %%
# What's the median video share count of each author ban status?
data.groupby(['author_ban_status']).median(numeric_only=True)[['video_share_count']]
# Out:
#                    video_share_count
# author_ban_status
# active                         437.0
# banned                       14468.0
# under review                  9444.0

# %% [raw]
# Question: What do I notice about the share count of banned authors, compared to that of active authors? Explore this in more depth.
#
# A major pattern is that banned authors have much higher share counts than active authors.
#
# Median share count comparison
# Active authors: 437 shares
# Banned authors: 14,468 shares
# Under review authors: 9,444 shares
#
# This means the typical video from a banned author is shared far more often than the typical video from an active author.
#
# Mean share count comparison
# Active authors: 14,111 shares
# Banned authors: 29,999 shares
# Under review authors: 25,775 shares
#
# The mean also shows the same trend—videos from banned authors receive significantly more shares.
#
# What this suggests
#
# Videos from banned authors tend to spread much more widely across the platform.
#
# Since sharing helps content reach more users, this may indicate that harmful, misleading, or sensational content spreads quickly and gains attention before moderation actions occur.
#
# Why this might happen
#
# Possible reasons include:
#
# controversial or shocking claims encourage more sharing
# misinformation often spreads faster because it grabs attention
# viral content is more likely to be reviewed by moderators
# accounts posting high-engagement harmful content may be banned after the content spreads
#
# This aligns with the earlier finding that claim-based videos are more associated with banned authors.
#
# Another important observation
#
# The gap between active (437) and banned (14,468) is extremely large, which suggests this is not a small difference—it is a strong relationship.
#
# This implies that high share counts may be connected to moderation risk.
#
#
# Use groupby() to group the data by author_ban_status, then use agg() to get the count, mean, and median of each of the following columns:
#
# video_view_count
# video_like_count
# video_share_count
# Remember, the argument for the agg() function is a dictionary whose keys are columns. The values for each column are a list of the calculations you want to perform.

# %%
data.groupby(['author_ban_status']).agg({'video_view_count':['count','mean','median'],'video_like_count':['count','mean','median'],'video_share_count':['count','mean','median']})
# Out:
#                   video_view_count                          video_like_count  \
#                              count           mean    median            count
# author_ban_status
# active                       15383  215927.039524    8616.0            15383
# banned                        1635  445845.439144  448201.0             1635
# under review                  2066  392204.836399  365245.5             2066
#
#                                            video_share_count                \
#                             mean    median             count          mean
# author_ban_status
# active              71036.533836    2222.0             15383  14111.466164
# banned             153017.236697  105573.0              1635  29998.942508
# under review       128718.050339   71204.5              2066  25774.696999
#
#
#                     median
# author_ban_status
# active               437.0
# banned             14468.0
# under review        9444.0

# %% [raw]
# Question: What do you notice about the number of views, likes, and shares for banned authors compared to active authors?
#
# A strong pattern is that banned authors consistently have much higher views, likes, and shares than active authors.
#
# Comparing active vs. banned authors
# Video views
# Active authors
# Mean: 215,927
# Median: 8,616
# Banned authors
# Mean: 445,845
# Median: 448,201
#
# Banned authors receive about twice the average views, and their median is dramatically higher than active authors.
#
# Video likes
# Active authors
# Mean: 71,037
# Median: 2,222
# Banned authors
# Mean: 153,017
# Median: 105,573
#
# Banned authors also receive far more likes, suggesting their content generates much stronger engagement.
#
# Video shares
# Active authors
# Mean: 14,111
# Median: 437
# Banned authors
# Mean: 29,999
# Median: 14,468
#
# This is one of the biggest differences—videos from banned authors are shared far more often than those from active authors.
#
# What this suggests
#
# Content from banned authors tends to spread much more widely across the platform.
#
# Higher views, likes, and especially shares may indicate:
#
# controversial content
# sensational claims
# misinformation
# highly viral but policy-violating posts
#
# These types of videos often attract attention quickly and may lead to moderation actions.
#
# Another important observation
#
# For active authors, the mean is much higher than the median, showing strong outliers.
#
# For banned authors, the mean and median are much closer—especially for views—which suggests high engagement is common across many banned accounts, not just caused by a few viral posts.
#
#
# Now, create three new columns to help better understand engagement rates:
#
# likes_per_view: represents the number of likes divided by the number of views for each video
# comments_per_view: represents the number of comments divided by the number of views for each video
# shares_per_view: represents the number of shares divided by the number of views for each video

# %%
# Create a likes_per_view column
data['likes_per_view']=data['video_like_count']/data['video_view_count']

# Create a comments_per_view column
data['comments_per_view']=data['video_comment_count']/data['video_view_count']

# Create a shares_per_view column
data['shares_per_view']=data['video_share_count']/data['video_view_count']

# %% [raw]
# Use groupby() to compile the information in each of the three newly created columns for each combination of categories of claim status and author ban status, then use agg() to calculate the count, the mean, and the median of each group.

# %%
data.groupby(['claim_status','author_ban_status']).agg({'video_like_count':['count','mean','median'],'video_comment_count':['count','mean','median'],'video_share_count':['count','mean','median']})
# Out:
#                                video_like_count                           \
#                                           count           mean    median
# claim_status author_ban_status
# claim        active                        6566  164960.302924  121943.0
#              banned                        1439  173719.102849  132044.0
#              under review                  1603  165566.954460  125882.0
# opinion      active                        8817    1091.714982     820.0
#              banned                         196    1027.515306     799.5
#              under review                   463    1139.663067     876.0
#
#                                video_comment_count                     \
#                                              count        mean median
# claim_status author_ban_status
# claim        active                           6566  687.827901  286.0
#              banned                           1439  698.402363  296.0
# ...

# %% [raw]
# Question: How does the data for claim videos and opinion videos compare or differ? Consider views, comments, likes, and shares.
#
# The data shows a very large difference between claim videos and opinion videos across views, likes, comments, and shares.
#
# Main pattern
#
# Claim videos receive dramatically more engagement than opinion videos, regardless of whether the author is active, banned, or under review.
#
# Comparing Claim vs. Opinion Videos
# 1. Likes
# Claim videos (active authors)
# Mean: 164,960
# Median: 121,943
# Opinion videos (active authors)
# Mean: 1,092
# Median: 820
#
# Claim videos receive enormously more likes—well over 100 times more.
#
# This same pattern holds for banned and under-review authors.
#
# 2. Comments
# Claim videos (active authors)
# Mean: 688
# Median: 286
# Opinion videos (active authors)
# Mean: 2.7
# Median: 1
#
# Claim videos generate far more discussion and interaction.
#
# Opinion videos receive almost no comments in comparison.
#
# 3. Shares
# Claim videos (active authors)
# Mean: 32,769
# Median: 17,774
# Opinion videos (active authors)
# Mean: 217
# Median: 121
#
# This is one of the biggest differences.
#
# Claim videos are shared far more often, meaning they spread much more widely across the platform.
#
# 4. Across author ban status
#
# For claim videos, engagement stays high across:
#
# active
# banned
# under review
#
# For opinion videos, engagement remains low across all author statuses.
#
# This suggests that the biggest driver of engagement is the content type (claim vs. opinion) more than the author’s moderation status.
#
# What this suggests
#
# Claim videos likely contain:
#
# surprising facts
# controversial statements
# misinformation
# sensational content
#
# These naturally attract more attention and encourage users to:
#
# like
# comment
# share
#
# Opinion videos are usually personal beliefs and tend to generate much less viral engagement.
#
# Overall conclusion
#
# Claim videos outperform opinion videos by a massive margin in likes, comments, and shares.
